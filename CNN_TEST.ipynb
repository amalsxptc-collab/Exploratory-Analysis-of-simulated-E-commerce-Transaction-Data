# %% [markdown]
# ## 🟢 Q1. CNN Intuition
#
# Explain in your own words:
# - What is a **convolution operation**?
# - What is the purpose of **filters/kernels**?
# - Why do we use **pooling layers**?
# - How does CNN differ from a fully connected (Dense) neural network?
#
# ---
#
# ## 🟢 Q2. Create a Simple CNN Model
#
# Using TensorFlow/Keras, build a CNN for image classification on the **MNIST dataset**.
#
# ```python
# import tensorflow as tf
# from tensorflow.keras import layers, models
# from tensorflow.keras.datasets import mnist
#
# # Load dataset
# (x_train, y_train), (x_test, y_test) = mnist.load_data()
#
# # TODO: reshape and normalize images
# # CNN expects input (batch, height, width, channels)
#
# # Build model
# model = models.Sequential([
#     # TODO: Add a Conv2D layer
#     # TODO: Add a MaxPooling2D layer
#     # TODO: Flatten, Dense(64, relu), and Dense(10, softmax)
# ])
#
# model.summary()
# ```
#
# ---
#
# ## 🟢 Q3. Compile and Train the Model
#
# Use Adam optimizer and sparse categorical crossentropy loss.
#
# ```python
# # TODO: Compile and train
# # model.compile(...)
# # history = model.fit(...)
# ```
#
# Plot training and validation accuracy.
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.title('CNN Training Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.show()
# ```
#
# ---
#
# ## 🟡 Q4. Add Regularization
#
# Try to reduce overfitting by adding **Dropout** and **BatchNormalization** layers.
#
# ```python
# # TODO: Modify CNN with Dropout(0.3) and BatchNormalization
# ```
#
# Train again and compare results.
#
# ---
#
# ## 🟡 Q5. Try CIFAR-10 Dataset
#
# Now repeat the same CNN structure for **CIFAR-10** dataset (RGB images).
#
# ```python
# from tensorflow.keras.datasets import cifar10
#
# (x_train, y_train), (x_test, y_test) = cifar10.load_data()
#
# # TODO: Normalize and build CNN (input_shape=(32,32,3))
# ```
#
# Which dataset was harder to train — MNIST or CIFAR-10? Why?
#
# ---
#
# ## 🟠 Q6. Visualization of Feature Maps
#
# Visualize the output feature maps of the **first convolutional layer**.
#
# ```python
# # TODO: Create a model to extract feature maps from the first Conv2D layer
# # model_feature = tf.keras.Model(inputs=model.input, outputs=model.layers[0].output)
# # feature_maps = model_feature.predict(x_test[:1])
#
# # Plot feature maps
# import matplotlib.pyplot as plt
#
# # Example: visualize first 6 feature maps
# # for i in range(6):
# #     plt.subplot(1,6,i+1)
# #     plt.imshow(feature_maps[0,:,:,i], cmap='gray')
# #     plt.axis('off')
# # plt.show()
# ```
#
# Explain what you observe in your own words.
#
# ---
#
# ## 🔵 Q7. Transfer Learning (Bonus)
#
# Use a pretrained model like **MobileNetV2** on CIFAR-10 data.
#
# ```python
# from tensorflow.keras.applications import MobileNetV2
#
# base = MobileNetV2(weights='imagenet', include_top=False, input_shape=(96,96,3))
# base.trainable = False
#
# x = layers.GlobalAveragePooling2D()(base.output)
# x = layers.Dense(128, activation='relu')(x)
# out = layers.Dense(10, activation='softmax')(x)
#
# model_tl = models.Model(inputs=base.input, outputs=out)
# model_tl.summary()
# ```
#
# Explain why freezing the base layers helps training.

# %% [markdown]
# Q1. CNN Intuition
#
# Explain in your own words:
#
#
#
# What is a convolution operation?
#
# A convolution is a mathematical operation used to extract the pattern(features)from an image.you slide a small filter(kernel)over the image ,multiply it value with the image pixels and sum of them, this help the network detect the edges, corners,textures, etc.
#
#
#
#
# What is the purpose of filters/kernels?
#
# *filter act like" feature detectors"
# * each filters learn to detect the specific feature like
#          edges
#          corners
#          textures., etc
#
#
#
# Why do we use pooling layers?
#
# pooling layers reduce the size of the featured map while keeping important information
#
# this helps
#
# Reduce computation
# prevent overfitting
# make the model focus on what is present rather than where it.
#
#
#
# How does CNN differ from a fully connected (Dense) neural network?
#
# feature                  CNN                        fully connected network
#
# Input               images(spatial data)                 flattness vector
#
#
# connection      local(sees part of image)   every neuron connected to other
#
#
# parameter       fewer                             many
#
# work best for   image,vedio data                     tabular,structured data

# %% [markdown]
# 2.create simple CNN model MNIST

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist

# load MNIST dataset
(x_train, y_train), (x_test,y_test) = mnist.load_data()

# reshape and normalize
x_train = x_train.reshape (-1, 28, 28, 1).astype('float32')/255.0
x_test = x_test.reshape (-1, 28, 28, 1).astype('float32')/255.0

# Build CNN model
model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape = (28, 28, 1)),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense (64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.summary()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
